# %% [markdown]
# ### I am importing the interest rate and the consumer price index into my data. I am using the notes from Project 6 and I am hoping to be able to make some more unique functions that I have created going forward with this project. But for now, I will use your code.

# %% [markdown]
# ### The goal of this project is to investigate how monitary policy and fiscal policy have been used to effect macroeconomic indicators. I will be using the inflation rate as the key indicator in my analysis. I am interetsed in learning about different policies and how they have changed over the last 60 years. I feel like I will get a good understanding of what are some trands thrrough the initial graphs.

# %% [markdown]
# ### I am importing all libraries I am using. I am going to use my data from FRED using pandas_datareader.data. I will use data since 1960 to present for my datasets. I decided to start with the Core CPI and the Monetary Base. The Core CPI is the consumer price index without the energy and the food sectors. I am using this variable because I am concerned with the genereal variablity of price changes and not price changes from sectors that change dramatically over time. I might change this before the final paper, but I have to decide first. Also, I could add the CPI with the energy and food sectors in at a later time. The monetary base is the amount of currency that is in either the central bank's reserves or in the general public. This will allow us to see how the government has put more money into the economy.

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

def gather_data(data_codes, start, end = datetime.datetime.today(), freq = "A"):
    i = 0
    for key, val in data_codes.items():
        if i == 0:
            df = web.DataReader(val, "fred", start, end).resample(freq).mean()
            df.rename(columns = {val:key}, inplace = True) 
            i = None
        else:
            df[key] = web.DataReader(val, "fred", start, end).resample(freq).mean()

    return df

def bil_to_mil(series):
    return series.mul(10**3)

data_codes  = {"Core CPI": "CPILFESL",
               "Monetary Base (Millions of Dollars)": "BOGMBASE"}

start = datetime.datetime(1960, 1, 1)
end = datetime.datetime.today()

data = gather_data(data_codes = data_codes, start = start, end = end, freq = "Y")

# %%
data[["Monetary Base (Billions of Dollars)"]] = (data["Monetary Base (Millions of Dollars)"]).div(1000)
updated_data = data[["Core CPI", "Monetary Base (Billions of Dollars)"]]
updated_data
# Out:
#               Core CPI  Monetary Base (Billions of Dollars)
# DATE
# 1960-12-31   30.641667                            50.008333
# 1961-12-31   31.000000                            49.308333
# 1962-12-31   31.400000                            50.933333
# 1963-12-31   31.808333                            52.441667
# 1964-12-31   32.300000                            55.183333
# ...                ...                                  ...
# 2017-12-31  252.169417                          3810.466667
# 2018-12-31  257.563667                          3641.116667
# 2019-12-31  263.208750                          3301.433333
# 2020-12-31  267.699750                          4615.075000
# 2021-12-31  274.686000                          5888.000000
#
# [62 rows x 2 columns]

# %% [markdown]
# ### Here we can see the linear graphs for the table above.

# %%
for key in updated_data:
    data[key].plot(figsize = (32,24), fontsize = 25)
    plt.title(key, fontsize = 32)
    plt.xlabel("Date", fontsize = 32)
    plt.axis()
    plt.show()
    plt.close()

# %% [markdown]
# ### The graphs above are not that useful, so I logged the data for the two datasets so that I can see the rate of change in order to try to get a better picture of what is happening with the data.

# %%
data["Core CPI (Logged)"] = np.log(data["Core CPI"])
data["Monetary Base (Logged)"] = np.log(data["Monetary Base (Billions of Dollars)"])
updated_dataset = data[["Core CPI (Logged)", "Monetary Base (Billions of Dollars)"]]

# %%
for key in updated_dataset:
    data[key].plot(figsize = (32,24), fontsize = 25)
    plt.title(key, fontsize = 32)
    plt.xlabel("Date", fontsize = 32)
    plt.axis()
    plt.show()
    plt.close()

# %% [markdown]
# ### As we can see here, there is a dramatic shift in the monetary base as it has been increased dramatically in response to both the financial crisis and COVID-19. Those weren't the only crises during the last 60 years, but there is an obvious increases in the monetary base which shows a difference between policy before the crisis and since the fiancial crisis. I hope to learn about what type of policies have led to these changes, and as to whether they are good changes or not. The answer to either of those questions might be very difficult, but I want to research monetary policy and learn more about modern theories.

# %% [markdown]
# ## What is the difference between Fiscal and Monetary policy?

# %% [markdown]
# ### Fiscal policy are the policies that deal with taxation and government spending, so government revenue and government expenditures. These policies usually come through the legislative or the exuctive branch. It is noteworthy that federal, state, and local governments could have fiscal policies that vary greatly. Monetary policy deals with the federal reserves making policy that shape their macroeconomic goals. Some gaols could be to decrease the price level or increase inflation.

# %% [markdown]
# ## An introduction into how fiscal policy is created from a public choice perspective

# %% [markdown]
# ###  Fiscal policies are made in a game of polictics, and it is rational to assume that people make tradeoffs in politics as political players tend to make agreements in order to try to accomplish their main goals. They will often give on issues that are of not as high importnance to them, such as a large, coastal city congressperson giving in on an agricultural issue and gaining support on a pro-port bill from a midwestern congressperson. These types of exchanges can be thought of as similar to positive-sum exchanges that are seen in everyday life.
#
# ### Given this basic framework in mind, it is easy to see how Fiscal policy issues could work in a way that is counter-productive. This could happen if a Fiscal policy is agreed upon by the majority (e.g., the bill is passed) of the legislation. But in the process, there are going to be people that will vote for other bills that previosly they would not have voted for, and this sort of calling in the favors could lead to two bills being passed that offset the goals of eachh other. Suppose that one bill was passed that increased income tax and another bill was passed that decreased sales tax. This might have kept the overall revenue for the governemnt at about the same, depsite the (assumed) intention of one of the bills was to increase revenue. Likewise the other bill wanted to decrease governmnet income, and it failed too.
#
# ### It is possible to see that policial players in the obove scenario could make a positive-sum exchange; therefore, they are motivated to behave in a similar way in the future. Wile the overall outcome might have had some reprecusions in the short-term, such as one bill going into effect before the other bill, but in this example there was a neutral benefit (in terms of the perceived goals of the political players). But since the players are incentivized to continue this trend, it likely will continue.

# %% [markdown]
# ## What is the relationship between Fiscal and Monetary policy?

# %% [markdown]
# ### This question is tricky as there are many factors in play when these policies are being made. But there is a pattern that Fiscal policy is created in a give-take enviroment as it is made by political players. Monetary policy, however, is suposed to be different as it is designed for non-political parties to create the policies.

# %% [markdown]
# # What do I plan on doing next?

# %% [markdown]
# ### Well, I want to add more macroeconomic variables, but first I must do more research on the basics of monetary policy and how its decisions are made. Also, I want ot add some sources and clean-up my section about public choice. I am interested in seeing where this project takes me as I already feel like I have learned a lot even though as I have only touched the surface. I also am trying to retrain my self to try to read harder material slower so I can comprehend it better (you mentioned oding this when we met in your office). I think this will help me as I continue this project and especially as I read morescholary work on monetary theory.
